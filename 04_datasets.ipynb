# %%
import pandas as pd

import duckdb

# %% [markdown]
# El objetivo de este notebook es crear nuevas clases dataset para distintas DAOs. Vamos a usar el dataset de Andrew en [Kaggle](https://www.kaggle.com/datasets/oiudoiajd/daos-census). Como las tablas son tan grandes (varios GB) no podemos usar `pd.read_parquet`

# %%
# Merging all tables into one database
db = duckdb.connect(database=':memory:', read_only=False)
db.execute("CREATE VIEW votes AS SELECT * FROM parquet_scan('{}')".format('data/daos-census/raw/votes.parquet'))
db.execute("CREATE VIEW proposals AS SELECT * FROM parquet_scan('{}')".format('data/daos-census/raw/proposals.parquet'))
db.execute("CREATE VIEW deployments AS SELECT * FROM parquet_scan('{}')".format('data/daos-census/raw/deployments.parquet'))

# %%
def get_columns_from_table(table_name):
    return db.execute(f"""
        SELECT column_name, data_type FROM information_schema.columns WHERE table_name='{table_name}'
    """).fetchdf().set_index('column_name')['data_type']

print(get_columns_from_table('votes'))
print(get_columns_from_table('proposals'))
# Out:
# column_name
# id                        VARCHAR
# proposal_id               VARCHAR
# deployment_id             VARCHAR
# platform_vote_id          VARCHAR
# voter                     VARCHAR
# date                    TIMESTAMP
# choice                    VARCHAR
# weight              DECIMAL(38,4)
# Name: data_type, dtype: object
# column_name
# id                        VARCHAR
# deployment_id             VARCHAR
# platform_proposal_id      VARCHAR
# author                    VARCHAR
# date                    TIMESTAMP
# votes_count                BIGINT
# Name: data_type, dtype: object

# %%
db.execute("""
SELECT * FROM deployments
ORDER BY proposals_count DESC
LIMIT 30
""").fetchdf()
# Out:
#                                       id  platform  \
# 0   c37abcdd-a36b-51fc-8fa6-2c3ecb780df0   daohaus
# 1   e2ec62ae-9b29-5f3a-a541-58678bb64a1b  snapshot
# 2   41fd8de5-f8e2-5023-86a3-825c49e9ad7f  snapshot
# 3   5deda895-4531-539a-b7dc-88797456ded7  daostack
# 4   17dba91a-e68f-50f6-8c1d-2d7fa57ab5fb  snapshot
# 5   d3229595-ac4c-55bf-9808-386fc5603bd1  daostack
# 6   d8a985e4-3cc2-542a-9cb4-3e024577fb3c    realms
# 7   7bfe40ed-eb25-546d-b5e0-7db022252f49   daohaus
# 8   51625fff-ef9e-58cd-9dda-0dc68ab75bb2    aragon
# 9   4ea69b08-fa7f-5daa-96d5-9515ded0076b  snapshot
# 10  a0c17bd7-00bb-5b89-b639-d85925ec638c  snapshot
# 11  0c40474f-e4a0-540f-ab2f-0451336464f7  snapshot
# 12  7b930871-5e1b-5efe-af9a-dc5413460604  snapshot
# 13  5ecb2cca-8b8a-5c67-8867-569e5ca0a8ae  snapshot
# 14  899cc74b-f242-5fd2-a270-763436927977   daohaus
# 15  6276d415-d5f2-5f2f-8d33-3c327f152de6  snapshot
# 16  6b341057-a48e-59a4-96d9-eb42e0e4f602  snapshot
# 17  6da30872-de18-5f44-92cf-9d9f2556b9c4  snapshot
# 18  c7d15fda-5697-5957-99d9-c853bb6143d4    aragon
# 19  7895e987-33dc-5576-8a1c-52982bf06483    aragon
# 20  11d85b2d-2dcc-5177-935a-943361fa098b   daohaus
# 21  5217d9e6-0191-55a6-a76e-1a9c6d5ee510    realms
# 22  828689d9-d8d3-52c8-a8e0-8c2d2b294d35  snapshot
# 23  792aa223-1e66-51a1-bbf1-1c1dc47cd7e8  snapshot
# 24  2c948d4e-88c8-5f91-8fe0-03d66da1a7ef  snapshot
# 25  9563b722-69c8-5d1c-86a3-1cdec1e9a966  snapshot
# 26  83c92429-127e-5cab-93ea-fa52c1ca772a  snapshot
# 27  b3e91dd7-dc75-5b20-9b92-ff967d472cec   daohaus
# 28  fc7ca377-ce11-5c7c-b2e4-99173da23e50    realms
# 29  377e7181-37e0-504d-b494-d26df613abdc  snapshot
#
#                                platform_deployment_id                   name  \
# 0          0x1b975a9daf25e7b01e0a6c72d657ff74925327a8    DEAD FoundationsDAO
# 1                                        cakevote.eth            PancakeSwap
# 2                                    snapshot.dcl.eth           Decentraland
# 3          0xe716ec63c5673b3a4732d22909b38d779fa47c3f                 xDXdao
# 4                                      index-coop.eth             Index Coop
# 5          0x519b70055af55a007110b4ff99b0ea33071c720a                  dxDAO
# 6   GovER5Lthms3bLBqWub97yVrMmEogzX7xNjdXpPPCVZw_G...            UXDProtocol
# 7          0x7961b6c69ec7d7203cbecc4f3bf30755713a3822       DAOSquare Grants
# 8          0x1c26fde2ce92cd1d932a0afb8367108eac7f369b                    NaN
# 9                                           gm365.eth                 gm DAO
# 10                                          frami.eth  frami y otras hierbas
# 11                                      apollodao.eth              WEALTHDAO
# 12                                       huwacoin.eth               HUWA-DAO
# 13                                        maturka.eth                 9K DAO
# 14         0x4570b4faf71e23942b8b9f934b47ccedf7540162    MetaCartel Ventures
# 15                                         toniya.eth             Klaytn Dex
# 16                                       balancer.eth               Balancer
# 17                                  bancornetwork.eth                 Bancor
# 18         0xbaf2eb7b0649b8c28970e7d9e8f5dee9b6f6d9fe                   NFTX
# 19         0x49c8c959ce8692978e4f3b169ffd179ec241adaf                    NaN
# 20         0xfe1084bc16427e5eb7f13fc19bcd4e641f7d571f             Raid Guild
# 21  GMnke6kxYvqoAXgbFGnu84QzvNHoqqTnijWSXYYTFQbB_B...               MonkeDAO
# 22                                          sdbal.eth          Stake DAO BAL
# 23                                          ppyaa.eth                 PaoPao
# 24                                       lemu.dcl.eth    dcl.governance.test
# 25                                        eth6888.eth             lovebnbdao
# 26                                    bentfinance.eth           Bent Finance
# 27         0x71c41878fcbfc1c7ab3c70e972e3fd1377ab8280                  Plaza
# 28  GqTPL6qRf5aUuqscLh8Rg2HTxPUXfhhAXDptTLhp1t2J_D...                  Mango
# 29                                     aavegotchi.eth             Aavegotchi
#
#                                               website  \
# 0                                                 nan
# 1                 https://snapshot.org/#/cakevote.eth
# 2             https://snapshot.org/#/snapshot.dcl.eth
# 3                                                 nan
# 4               https://snapshot.org/#/index-coop.eth
# 5                                                 nan
# 6                                                 NaN
# 7                                                 nan
# 8   https://etherscan.io/address/0x1c26fde2ce92cd1...
# 9                    https://snapshot.org/#/gm365.eth
# 10                   https://snapshot.org/#/frami.eth
# 11               https://snapshot.org/#/apollodao.eth
# 12                https://snapshot.org/#/huwacoin.eth
# 13                 https://snapshot.org/#/maturka.eth
# 14                                                nan
# 15                  https://snapshot.org/#/toniya.eth
# 16                https://snapshot.org/#/balancer.eth
# 17           https://snapshot.org/#/bancornetwork.eth
# 18  https://etherscan.io/address/0xbaf2eb7b0649b8c...
# 19  https://etherscan.io/address/0x49c8c959ce86929...
# 20                                                nan
# 21                                                NaN
# 22                   https://snapshot.org/#/sdbal.eth
# 23                   https://snapshot.org/#/ppyaa.eth
# 24                https://snapshot.org/#/lemu.dcl.eth
# 25                 https://snapshot.org/#/eth6888.eth
# 26             https://snapshot.org/#/bentfinance.eth
# 27                                                nan
# 28                                                NaN
# 29              https://snapshot.org/#/aavegotchi.eth
#
#                                     additional  votes_count  proposals_count
# 0                   network: xdai version: 2.0        17738            29681
# 1                                          nan       532830             2744
# 2                                 decentraland       116560             1962
# 3                                          nan         5913             1438
# 4        indexcoop, https://www.indexcoop.com/        24031              918
# 5                                          nan         2566              918
# 6                                          NaN         2562              916
# 7                   network: xdai version: 2.1          702              880
# 8                                          nan         1331              860
# 9                                          nan        91546              730
# 10                                         nan          203              637
# 11                                zhiyuan_2007         4008              631
# 12                                         nan         4151              624
# 13                      https://t.me/Pro_Deng1       102321              592
# 14               network: mainnet version: 2.0         1580              558
# 15              https://www.klaytn.foundation/         2660              526
# 16              balancer, https://balancer.fi/       111987              509
# 17              bancor, https://bancor.network        30942              500
# 18                                         nan          449              494
# 19                                         nan          922              478
# 20                  network: xdai version: 2.1         1398              466
# 21                                         NaN         1096              462
# 22                                         nan          178              441
# 23                                         nan        28173              428
# 24                                         nan          204              423
# 25                                         nan         5045              420
# 26  BENT_Finance, https://app.bentfinance.com/          661              419
# 27                  network: xdai version: 2.1          534              417
# 28                                         NaN         1182              412
# 29          aavegotchi, https://aavegotchi.com       305499              407

# %%
def best_daos_for_recsys(min_proposals=300, min_voters=50, min_density=0.0001, order_by='proposals_count', limit=10000):
    df = db.execute(f"""
    WITH G AS (
        SELECT deployments.*, COUNT(DISTINCT votes.voter) AS voters_count
        FROM deployments
        LEFT JOIN votes ON (deployments.id = votes.deployment_id)
        WHERE proposals_count > {min_proposals}
        GROUP BY deployments.*
    )
    SELECT *, 
        voters_count + proposals_count AS nodes, 
        2*(votes_count)/((voters_count + proposals_count)*(voters_count + proposals_count-1)) AS density, 
        votes_count/proposals_count AS vpp, 
        votes_count/voters_count AS vpv
    FROM G
    WHERE density > {min_density} AND voters_count > {min_voters}
    ORDER BY {order_by} DESC
    LIMIT {limit}
    """).fetchdf()

    df['milli density'] = 1000 * df['density']

    return df

best_daos_for_recsys().head(10)
# Out:
#                                      id  platform  \
# 0  41fd8de5-f8e2-5023-86a3-825c49e9ad7f  snapshot
# 1  5deda895-4531-539a-b7dc-88797456ded7  daostack
# 2  d3229595-ac4c-55bf-9808-386fc5603bd1  daostack
# 3  17dba91a-e68f-50f6-8c1d-2d7fa57ab5fb  snapshot
# 4  4ea69b08-fa7f-5daa-96d5-9515ded0076b  snapshot
# 5  0c40474f-e4a0-540f-ab2f-0451336464f7  snapshot
# 6  7b930871-5e1b-5efe-af9a-dc5413460604  snapshot
# 7  5ecb2cca-8b8a-5c67-8867-569e5ca0a8ae  snapshot
# 8  899cc74b-f242-5fd2-a270-763436927977   daohaus
# 9  6276d415-d5f2-5f2f-8d33-3c327f152de6  snapshot
#
#                        platform_deployment_id                 name  \
# 0                            snapshot.dcl.eth         Decentraland
# 1  0xe716ec63c5673b3a4732d22909b38d779fa47c3f               xDXdao
# 2  0x519b70055af55a007110b4ff99b0ea33071c720a                dxDAO
# 3                              index-coop.eth           Index Coop
# 4                                   gm365.eth               gm DAO
# 5                               apollodao.eth            WEALTHDAO
# 6                                huwacoin.eth             HUWA-DAO
# 7                                 maturka.eth               9K DAO
# 8  0x4570b4faf71e23942b8b9f934b47ccedf7540162  MetaCartel Ventures
# 9                                  toniya.eth           Klaytn Dex
#
#                                    website  \
# 0  https://snapshot.org/#/snapshot.dcl.eth
# 1                                      nan
# 2                                      nan
# 3    https://snapshot.org/#/index-coop.eth
# 4         https://snapshot.org/#/gm365.eth
# 5     https://snapshot.org/#/apollodao.eth
# 6      https://snapshot.org/#/huwacoin.eth
# 7       https://snapshot.org/#/maturka.eth
# 8                                      nan
# 9        https://snapshot.org/#/toniya.eth
#
#                               additional  votes_count  proposals_count  \
# 0                           decentraland       116560             1962
# 1                                    nan         5913             1438
# 2                                    nan         2566              918
# 3  indexcoop, https://www.indexcoop.com/        24031              918
# 4                                    nan        91546              730
# 5                           zhiyuan_2007         4008              631
# 6                                    nan         4151              624
# 7                 https://t.me/Pro_Deng1       102321              592
# 8          network: mainnet version: 2.0         1580              558
# 9         https://www.klaytn.foundation/         2660              526
#
#    voters_count  nodes   density         vpp        vpv  milli density
# 0          7268   9230  0.002737   59.408767  16.037424       2.736675
# 1            92   1530  0.005055    4.111961  64.271739       5.055207
# 2           134   1052  0.004642    2.795207  19.149254       4.641605
# 3          2871   3789  0.003349   26.177560   8.370254       3.348631
# 4          7711   8441  0.002570  125.405479  11.872131       2.569999
# 5          1041   1672  0.002869    6.351823   3.850144       2.869095
# 6          1331   1955  0.002173    6.652244   3.118708       2.173259
# 7          8170   8762  0.002666  172.839527  12.523990       2.665863
# 8            77    635  0.007849    2.831541  20.519481       7.849177
# 9           869   1395  0.002736    5.057034   3.060990       2.735739

# %%
def best_orgs_for_recsys(min_proposals=300, min_voters=50, min_density=0.0005, order_by='proposals_count', limit=10000):
    df = db.execute(f"""
    WITH G AS (WITH Gv AS (
            SELECT *
            FROM deployments
            LEFT JOIN votes ON (deployments.id = votes.deployment_id)
        )
        SELECT 
            name,
            COUNT(DISTINCT Gv.id) AS n_deploys,
            LIST(DISTINCT Gv.id) AS deploys,
            COUNT(DISTINCT Gv.proposal_id) AS proposals_count,
            COUNT(DISTINCT Gv.voter) AS voters_count,
            COUNT(*) AS votes_count,
        FROM Gv
        GROUP BY Gv.name
    )
    SELECT
        *,
        proposals_count + voters_count AS nodes,
        2*(votes_count)/((voters_count + proposals_count)*(voters_count + proposals_count-1)) AS density, 
        votes_count/proposals_count AS vpp, 
        votes_count/voters_count AS vpv
    FROM G
    WHERE density > {min_density} AND proposals_count > {min_proposals} AND voters_count > {min_voters}
    ORDER BY proposals_count DESC
    LIMIT 100000
    """).fetchdf().dropna()

    df['milli density'] = 1000 * df['density']

    return df

best_orgs_for_recsys()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                    name  n_deploys  \
# 0          Decentraland          3
# 1                xDXdao          1
# 2            Index Coop          2
# 3                 dxDAO          1
# 4                  Aave          3
# 5                gm DAO          3
# 6                9K DAO          1
# 7             WEALTHDAO          1
# 8   MetaCartel Ventures          3
# 9              HUWA-DAO          1
# 10             Balancer          2
# 11                 NFTX          3
# 12               Bancor          2
# 13           Klaytn Dex          1
# 14           Raid Guild          4
# 15                  bnb          5
# 16           Aavegotchi          3
# 17               PaoPao          1
# 18           lovebnbdao          1
# 19                 Lido          3
# 20             SharkDAO          1
# 21     MATIC Test Space          1
# 22               haidao          1
# 23        Genesis Alpha          1
# 24                Mango          1
# 25              Rosette          1
# 26                matic          5
# 27          JuiceboxDAO          1
# 28                 dOrg          3
# 29           MATIC 2021          1
# 30                 Frax          2
# 31             MaticDAO          2
# 32        MATIC DAO DAO          1
# 33         Bent Finance          1
# 34                   夜曲          1
# 35                WdDao          1
# 36    Good Morning News          1
# 37               skgame          1
# 38               BNB2.0          1
# 39         Aura Finance          1
# 40        loveeachother          1
# 41             pylygon1          1
# 42            Nouns Dao          1
#
#                                               deploys  proposals_count  \
# 0   [7117d5c4-de0e-5e4c-872d-40c3bd4b0200, 36a86d4...             2060
# 1              [5deda895-4531-539a-b7dc-88797456ded7]             1380
# 2   [17dba91a-e68f-50f6-8c1d-2d7fa57ab5fb, a25032f...              874
# 3              [d3229595-ac4c-55bf-9808-386fc5603bd1]              846
# 4   [73c10c98-7499-53b1-8643-c15d8b5dc5b7, b6c95a5...              725
# 5   [c3a8aa6c-1652-5834-a355-954bc422f1af, 360a8f2...              710
# 6              [5ecb2cca-8b8a-5c67-8867-569e5ca0a8ae]              590
# 7              [0c40474f-e4a0-540f-ab2f-0451336464f7]              585
# 8   [899cc74b-f242-5fd2-a270-763436927977, b96c148...              579
# 9              [7b930871-5e1b-5efe-af9a-dc5413460604]              572
# 10  [6b341057-a48e-59a4-96d9-eb42e0e4f602, ad55999...              509
# 11  [83c299c6-43f6-5b8e-9d96-091fa782aa92, c7d15fd...              500
# 12  [6da30872-de18-5f44-92cf-9d9f2556b9c4, f7dc26d...              497
# 13             [6276d415-d5f2-5f2f-8d33-3c327f152de6]              455
# 14  [9ad7fdf9-c2b2-5218-a66e-508ef16652bc, 11d85b2...              435
# 15  [06a53d83-7bd0-5e87-9b8f-f83f6e0f13fd, 96a694c...              433
# 16  [355c51b5-0e82-5962-b55e-84e6b1aaa27c, 377e718...              415
# 17             [792aa223-1e66-51a1-bbf1-1c1dc47cd7e8]              415
# 18             [9563b722-69c8-5d1c-86a3-1cdec1e9a966]              403
# 19  [3c653b79-5b4c-570b-8929-90ecb52a4d8d, e750819...              398
# 20             [58b96992-5a73-5109-9e69-f37a8732f806]              396
# 21             [8f4e6e1a-c4a6-5062-a296-685cdf3a0d1d]              365
# 22             [c30f49df-097a-54f7-8136-c19f8aa4b21d]              355
# 23             [1ff410f5-1c80-53cd-9558-d93d1f6de121]              355
# 24             [fc7ca377-ce11-5c7c-b2e4-99173da23e50]              352
# 25             [d2516188-9ff9-5ff9-b7f5-e65bbdc63f44]              337
# 26  [74340882-a6ef-55f2-b93e-9bcd3978dd5a, 7d20982...              336
# 27             [bb7802d6-3b4f-5625-a044-9e854a2109a7]              327
# 28  [5605fbf2-952a-54cd-b1f0-74c3382d543f, 7b09252...              326
# 29             [bb12b0d1-16ca-587d-ad1f-cdefc23ed298]              323
# 30  [9ff403bd-4d7a-51f3-8991-aaa46baf107d, 95423c4...              321
# 31  [793c2496-b468-56c1-9f11-746f5e1edc55, c7c2aa7...              320
# 32             [ce09a888-4493-5056-950f-2845ab5031f5]              317
# 33             [83c92429-127e-5cab-93ea-fa52c1ca772a]              316
# 34             [eff45f9e-b634-5bca-94a6-bcd6825c7266]              316
# 35             [22af89a1-4cd4-5af8-a5ac-a489f768beb8]              314
# 36             [80e598c8-570a-5919-8c1c-139f5d91fa7a]              311
# 37             [0b6b4bd1-a58b-55df-ac81-5560963b6017]              310
# 38             [7a9c9c55-feb1-5ab0-8172-5fbe33a23b9b]              309
# 39             [0ca3b44d-da0c-5efa-bbb8-e28355c34e23]              309
# 40             [8b0bd65a-0816-562f-8d4d-bfa33b5b34f8]              304
# 41             [f9881a70-cbb8-5d3a-8e66-a9a0329cc6b1]              303
# 42             [195dff68-95c4-5ab3-9f26-6bf7beb9c67a]              302
#
#     voters_count  votes_count  nodes   density          vpp        vpv  \
# 0           7334       116880   9394  0.002649    56.737864  15.936733
# 1             92         5913   1472  0.005462     4.284783  64.271739
# 2           2871        24032   3745  0.003428    27.496568   8.370603
# 3            134         2566    980  0.005349     3.033097  19.149254
# 4          77921      2053071  78646  0.000664  2831.822069  26.348109
# 5           7712        91548   8422  0.002582   128.940845  11.870851
# 6           8170       102321   8760  0.002667   173.425424  12.523990
# 7           1041         4008   1626  0.003034     6.851282   3.850144
# 8            124         2132    703  0.008640     3.682211  17.193548
# 9           1331         4151   1903  0.002294     7.256993   3.118708
# 10          9107       111988   9616  0.002422   220.015717  12.296914
# 11           501         1601   1001  0.003199     3.202000   3.195609
# 12          1092        30943   1589  0.024526    62.259557  28.336081
# 13           869         2660   1324  0.003037     5.846154   3.060990
# 14           129         1519    564  0.009568     3.491954  11.775194
# 15           592         1089   1025  0.002075     2.515012   1.839527
# 16         13251       307589  13666  0.003294   741.178313  23.212512
# 17           550        28173    965  0.060570    67.886747  51.223636
# 18          2163         5045   2566  0.001533    12.518610   2.332409
# 19          5792        56863   6190  0.002969   142.871859   9.817507
# 20           658         7577   1054  0.013654    19.133838  11.515198
# 21          2313         3490   2678  0.000974     9.561644   1.508863
# 22           616         2294    971  0.004871     6.461972   3.724026
# 23           128         2203    483  0.018926     6.205634  17.210938
# 24           187         1182    539  0.008152     3.357955   6.320856
# 25           299          559    636  0.002768     1.658754   1.869565
# 26          1835         2608   2171  0.001107     7.761905   1.421253
# 27           944        21507   1271  0.026648    65.770642  22.782839
# 28            91         1783    417  0.020557     5.469325  19.593407
# 29          1577         2971   1900  0.001647     9.198142   1.883957
# 30          1011        10185   1332  0.011490    31.728972  10.074184
# 31          1362         2164   1682  0.001531     6.762500   1.588840
# 32          1184         1492   1501  0.001325     4.706625   1.260135
# 33            97          661    413  0.007769     2.091772   6.814433
# 34          3757         5808   4073  0.000700    18.379747   1.545914
# 35           637          994    951  0.002200     3.165605   1.560440
# 36            67         1431    378  0.020083     4.601286  21.358209
# 37           434          674    744  0.002439     2.174194   1.552995
# 38          1342         3293   1651  0.002418    10.656958   2.453800
# 39           678         7677    987  0.015777    24.844660  11.323009
# 40           589         1282    893  0.003219     4.217105   2.176570
# 41           967        10651   1270  0.013218    35.151815  11.014478
# 42           588         9355    890  0.023647    30.976821  15.909864
#
#     milli density
# 0        2.649204
# 1        5.461569
# 2        3.427932
# 3        5.349065
# 4        0.663875
# 5        2.581665
# 6        2.667081
# 7        3.033778
# 8        8.640219
# 9        2.293683
# 10       2.422466
# 11       3.198801
# 12      24.525508
# 13       3.037133
# 14       9.567540
# 15       2.075076
# 16       3.294198
# 17      60.570163
# 18       1.533018
# 19       2.968579
# 20      13.653950
# 21       0.973636
# 22       4.871161
# 23      18.925629
# 24       8.152230
# 25       2.768286
# 26       1.107179
# 27      26.647751
# 28      20.556632
# 29       1.646850
# 30      11.489702
# 31       1.530712
# 32       1.325339
# 33       7.769341
# 34       0.700381
# 35       2.200454
# 36      20.083365
# 37       2.438530
# 38       2.417635
# 39      15.777111
# 40       3.218857
# 41      13.217674
# 42      23.647325

# %%
def get_deploys_with_name(name: str):
    return db.execute(f"""
    SELECT *
    FROM deployments
    WHERE name='{name}'
    """).fetchdf()

get_deploys_with_name('Decentraland')
# Out:
#                                      id  platform  \
# 0  41fd8de5-f8e2-5023-86a3-825c49e9ad7f  snapshot
# 1  36a86d4c-690b-5da9-87b5-cf2230328b17    aragon
# 2  7117d5c4-de0e-5e4c-872d-40c3bd4b0200  governor
#
#                        platform_deployment_id          name  \
# 0                            snapshot.dcl.eth  Decentraland
# 1  0xf47917b108ca4b820ccea2587546fbb9f7564b56  Decentraland
# 2        c584e902-7b8f-4fb0-b742-8fa364c94940  Decentraland
#
#                                              website    additional  \
# 0            https://snapshot.org/#/snapshot.dcl.eth  decentraland
# 1  https://etherscan.io/address/0xf47917b108ca4b8...           nan
# 2                                                nan           nan
#
#    votes_count  proposals_count
# 0       116560             1962
# 1          319              135
# 2            0                0

# %%
import torch
from torch_geometric.data import InMemoryDataset, HeteroData

class DAOCensus(InMemoryDataset):
    def __init__(self, root: str, name: str, platform: str=None):
        self._name = name
        self._platform = platform
        
        super().__init__(root)

        self.data = torch.load(self.processed_paths[0])

        from pathlib import Path
        Path(self.processed_paths[0]).unlink()

    def download(self):
        import kaggle
        kaggle.api.dataset_download_cli('oiudoiajd/daos-census', path=self.raw_dir, unzip=True)

    def process(self):
        import pandas as pd
        import duckdb

        db = duckdb.connect(database=':memory:', read_only=False)
        db.execute("CREATE VIEW deployments AS SELECT * FROM parquet_scan('{}')".format(self.raw_paths[0]))
        db.execute("CREATE VIEW votes AS SELECT * FROM parquet_scan('{}')".format(self.raw_paths[1]))
        db.execute("CREATE VIEW proposals AS SELECT * FROM parquet_scan('{}')".format(self.raw_paths[2]))

        cond = f"name='{self._name}'"
        if self._platform:
            cond += f" AND platform='{self._platform}'"

        dfv = db.execute(f"""
        SELECT platform, name, votes.*
        FROM deployments
        LEFT JOIN votes ON (deployments.id = votes.deployment_id)
        WHERE {cond}
        """).fetchdf().rename(columns=lambda x: x.replace('_id', ''))

        dfp = db.execute(f"""
        SELECT platform, name, proposals.*
        FROM deployments
        LEFT JOIN proposals ON (deployments.id = proposals.deployment_id)
        WHERE {cond}
        """).fetchdf().rename(columns=lambda x: x.replace('_id', ''))

        data = HeteroData()
        t = {}

        # display(dfp)
        
        dfv['voter'] = dfv['voter'].str.lower()
        dfp['author'] = dfp['author'].str.lower()

        prop_dtype = pd.api.types.CategoricalDtype(categories=dfp['id'])
        user_dtype = pd.api.types.CategoricalDtype(categories=set(dfv['voter']).union(dfp['author']))

        # voter <-> proposal (dfv)
        dfv['voter'] = dfv['voter'].astype(user_dtype)
        dfv['proposal'] = dfv['proposal'].astype(prop_dtype)

        data['user'].num_nodes = user_dtype.categories.size
        data['user'].voters = dfv['voter'].cat.codes.unique()
        data['proposal'].num_nodes = prop_dtype.categories.size
        
        t = torch.stack([
            torch.LongTensor(dfv['voter'].cat.codes),
            torch.LongTensor(dfv['proposal'].cat.codes)
        ])

        data['user', 'vote', 'proposal'].edge_index = t
        data['proposal', 'vote', 'user'].edge_index = t[(1,0), :]

        # author <-> proposal (dfp)
        dfp['author'] = dfp['author'].astype(user_dtype)
        dfp['id'] = dfp['id'].astype(prop_dtype)
        t = torch.stack([
            torch.LongTensor(dfp['author'].cat.codes),
            torch.LongTensor(dfp['id'].cat.codes),
        ])

        data['user'].authors = dfp['author'].cat.codes.unique()
        data['user', 'creates', 'proposal'].edge_index = t
        data['proposal', 'creates', 'user'].edge_index = t[(1,0), :]

        data.validate()
        assert not data.is_directed()
        assert not data.has_isolated_nodes()

        db.close()
        torch.save(data, self.processed_paths[0])

    @property
    def raw_file_names(self):
        return ["deployments.parquet", "votes.parquet", "proposals.parquet"]

    @property
    def processed_file_names(self) -> str:
        return f"daostack_votes_{self._name}.pt"

data = DAOCensus("./data/daos-census", 'Decentraland', 'snapshot')
data[0]
# Out:
# Processing...
# Done!
# HeteroData(
#   user={
#     num_nodes=7270,
#     voters=[7268],
#     authors=[2],
#   },
#   proposal={ num_nodes=1962 },
#   (user, vote, proposal)={ edge_index=[2, 116560] },
#   (proposal, vote, user)={ edge_index=[2, 116560] },
#   (user, creates, proposal)={ edge_index=[2, 1962] },
#   (proposal, creates, user)={ edge_index=[2, 1962] }
# )
